# %% [markdown]
# # Python Script to Mine Tweets

# %% [markdown]
# ## Let's first mine the tweets from the timeline.

# %% [markdown]
# Importing Tweepy - To mine twitter data we will be using Tweepy. To use Tweepy on your machine 'pip install' it through terminal.

# %%
import tweepy
from tweepy import OAuthHandler

# %% [markdown]
# Fill the X with data from Twitter API keys of your account. It can be found at developers.twitter.com

# %%
consumer_key = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX" 
consumer_secret = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
access_key = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
access_secret = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"

# %% [markdown]
# In order to authorise our app to access Twitter on our behalf, we need to use the OAuth interface

# %%
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)

# %%
#The api variable below is now our entry point for most of the operations we can perform with Twitter.
api = tweepy.API(auth)

# %% [markdown]
# Import JSONlines - where data is stored.

# %%
import json
import jsonlines

# %% [markdown]
# The storeTweets() function stores the tweets in a JSONlines file

# %%
def storeTweets(tweet):
    with open('output.jsonl', 'a') as outfile:
        json.dump(tweet,outfile)
        outfile.write('\n')

# %% [markdown]
# The mineTweets() functions takes a username and scans the username's timeline to mine all the tweets possible. It then call storeTweets() to dump it into JSONlines file.

# %%
def mineTweets(username):
    tweets = api.user_timeline(screen_name=username)
    for tweet in tweets:
        storeTweets(tweet._json)

# %% [markdown]
# The next line calls the mineTweets function with the twitter handle of @midasIIITD, it mines the tweets in the timeline and stores it in output.jsonl

# %%
mineTweets('midasIIITD')

# %% [markdown]
# ## We are done mining. Now let's print the data mined in a table from the JSONlines File.

# %% [markdown]
# We go through output.jsonl and append the data at the end of a variable data.

# %%
data=[];
with jsonlines.open('output.jsonl') as reader:
    for obj in reader:
        data.append(obj)

# %% [markdown]
# To display the data in a table we are using Pandas DataFrame, if you don't have it install using pip through terminal.

# %%
import pandas as pd
from pandas import DataFrame

# %% [markdown]
# Converting the data appended to a Panda's DataFrame.

# %%
df = pd.DataFrame.from_dict(data, orient='columns')

# %% [markdown]
# We are displaying the tweets in a table as shown below. The table displays the The text of the tweet, Date and time of the tweet, The number of favorites/likes, The number of retweets. The fifth column is the 'entities' which contains the 'media' attribute which shows if the tweet contains any images ('type'='photo').

# %%
df[['text', 'created_at','favorite_count','retweet_count','entities']]
# Out:
#                                                  text  \
# 0   We have emailed the task details to all candid...
# 1   RT @rfpvjr: Our NAACL paper on polarization in...
# 2   RT @kdnuggets: Effective Transfer Learning For...
# 3   RT @stanfordnlp: What’s new in @Stanford CS224...
# 4   RT @DeepMindAI: Today we're releasing a large-...
# 5   RT @ylecun: Congratulations Jitendra Malik !\n...
# 6   RT @IIITDelhi: Another chance to take admissio...
# 7   Dear @midasIIITD internship candidates who hav...
# 8   Looking forward to your paper submission to @I...
# 9   RT @ngrams: Reproducibility in multimedia rese...
# 10  Online application for https://t.co/DJFDrQsHZP...
# 11  RT @ACMMM19: A final reminder of the Reproduci...
# 12  RT @isarth23: Thanks for the support and help ...
# 13  Since SemEval-2019 will be held June 6-7, 2019...
# 14  +@aggarwal_kartik.\nCongrats! Wish you many mo...
# 15  RT @aggarwal_kartik: Our work (@midasIIITD ) a...
# ...
